# %%
import nest_asyncio

nest_asyncio.apply()

# %%
# pip install python-dotenv
from dotenv import find_dotenv, load_dotenv
load_dotenv(find_dotenv())
# Out:
# True

# %%
from graph_4 import graph, GraphState

resp = await graph.ainvoke(input=GraphState(question="Как обновить GigaChain?"))
resp['generation']
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[16], line 3
#       1 from graph_4 import graph, GraphState
# ----> 3 resp = await graph.ainvoke(input=GraphState(question="Как обновить GigaChain?"))
#       4 resp['generation']
#
# File ~/Documents/giga/gigachain_telegram_bot/venv/lib/python3.12/site-packages/langgraph/pregel/__init__.py:1980, in Pregel.ainvoke(self, input, config, stream_mode, output_keys, interrupt_before, interrupt_after, debug, **kwargs)
#    1978 else:
#    1979     chunks = []
# -> 1980 async for chunk in self.astream(
#    1981     input,
#    1982     config,
#    1983     stream_mode=stream_mode,
#    1984     output_keys=output_keys,
#    1985     interrupt_before=interrupt_before,
#    1986     interrupt_after=interrupt_after,
#    1987     debug=debug,
#    1988     **kwargs,
#    1989 ):
#    1990     if stream_mode == "values":
# ...
